# %% [markdown]
# <a href="https://colab.research.google.com/github/rabiyulfahimhasim786/linkedinscraper/blob/main/linkedinscraper_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import requests
from bs4 import BeautifulSoup

# %%
import random
user_agent_list =['Mozilla/5.0 (compatible; Sundance/0.9x)', 'Mozilla/5.0 (compatible; U; ABrowse 0.6; Syllable) AppleWebKit/420+ (KHTML, like Gecko)', 'Mozilla/5.0 (compatible; Windows; U; Windows NT 5.1; en-US; rv:1.8.1.2) Gecko/20070219', 'Mozilla/5.0 (compatible; Windows; U; Windows NT 6.2; WOW64; en-US; rv:12.0) Gecko/20120403211507 Firefox/12.0', 'Mozilla/5.0 (compatible; iCab 3.0.2; Macintosh; U; PPC Mac OS X)', 'Mozilla/5.0 (compatible; iCab 3.0.2; Macintosh; U; PPC Mac OS)', 'Mozilla/5.0 (compatible; iCab 3.0.3; Macintosh; U; PPC Mac OS X)', 'Mozilla/5.0 (compatible; iCab 3.0.3; Macintosh; U; PPC Mac OS)', 'Mozilla/5.0 (compatible; iCab 3.0.5; Macintosh; U; PPC Mac OS X)', 'Mozilla/5.0 (compatible; iCab 3.0.5; Macintosh; U; PPC Mac OS)', 'Mozilla/5.0 (iPad; CPU OS 5_1 like Mac OS X) AppleWebKit/534.46 (KHTML, like Gecko ) Version/5.1 Mobile/9B176 Safari/7534.48.3', 'Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25', 'Mozilla/5.0 (iPad; U; CPU OS 3_2 like Mac OS X; es-es) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7B360 Safari/531.21.10', 'Mozilla/5.0 (iPad; U; CPU OS 3_2 like Mac OS X; es-es) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7B367 Safari/531.21.10', 'Mozilla/5.0 (iPad; U; CPU OS 3_2_2 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7B500 Safari/53', 'Mozilla/5.0 (iPad;U;CPU OS 3_2_2 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7B500 Safari/531.21.10', 'Mozilla/5.0 (iPhone Simulator; U; CPU iPhone OS 3_2 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7D11 Safari/531.21.10', 'Mozilla/5.0 (iPhone; U; CPU OS 3_2 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7B334b Safari/531.21.10', 'Mozilla/5.0 (iPhone; U; CPU iPhone OS 4_1 like Mac OS X; en-us) AppleWebKit/532.9 (KHTML, like Gecko) Version/4.0.5 Mobile/8B117 Safari/6531.22.7', 'Mozilla/5.0 (iPhone; U; CPU iPhone OS 4_1 like Mac OS X; en-us) AppleWebKit/532.9 (KHTML, like Gecko) Version/4.0.5 Mobile/8B5097d Safari/6531.22.7', 'Mozilla/5.0 (iPhone; U; CPU iPhone OS 4_2_1 like Mac OS X; nb-no) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.2 Mobile/8C148a Safari/6533.18.5']

# %%
for i in range(1,2):
  #Pick a random user agent
  user_agent = random.choice(user_agent_list)
  headers = {'User-Agent': user_agent }
  print(user_agent)
# Out:
# Mozilla/5.0 (iPad; U; CPU OS 3_2_2 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Version/4.0.4 Mobile/7B500 Safari/53

# %%
url = 'https://www.linkedin.com/jobs/python-developer-jobs-greater-houston?currentJobId=3584717391&position=5&pageNum=0'
response = requests.get(url, headers = headers)
print(response)
soup = BeautifulSoup(response.content,'html.parser')
# Out:
# <Response [200]>

# %%
main_div=soup.find_all("div",class_="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card")
# articles=main_div.find_all("div",class_="articles")
joblink = []
for i in main_div:
  #b = i.find('a').get('href')'
  b= i.find('a')
  #print('https://www.simplyhired.com/'+b.attrs['href'])
  #c = 'https://www.simplyhired.com/'+b.attrs['href']
  # a.append(b.attrs['href'])
  joblink.append(b.attrs['href'])
print(joblink)
print(len(joblink))
# Out:
# ['https://www.linkedin.com/jobs/view/python-developer-at-donato-technologies-inc-3534800375?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=a7kj%2BTScgUm4TZyKGEpmIQ%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-teal-3580454578?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=K2uopErZwAD6rAWoTMxLWQ%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-mhk-tech-inc-3480612830?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=wNemgoSiyiAuKu3ersCj9g%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-remote-at-tensoriot-inc-3593022609?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=AJokef2DDzmb58lxJgpeUw%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-hybrid-tx-at-stellent-it-3584717391?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=Y9LK1%2BY1NzGmSjD2FGBnQQ%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-remote-at-the-dignify-solutions-llc-3569980779?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=INupXQJhoFH2GkrWc9odwA%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-fintech-llc-3418387917?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=z%2FJlXWV6OMfNEwQO9DdlCw%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-tekvivid-inc-3497356391?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=X3xVwWqsxX6r4O%2FreijF%2Fg%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-remote-wfh-at-get-it-recruit-information-technology-3586560628?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=HUdnShWGR7VLXrlji4XObw%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-extend-information-systems-inc-3480802978?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=S95R0tMtlN5rPlAgQO2uMw%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-with-aws-at-donato-technologies-inc-3534838411?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=RH49awI%2B%2F5iba9dAZOZpRQ%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-hermitage-infotech-3589717076?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=km9L0V%2BfohvnrMyaDf4wTw%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-engineer-at-mhk-tech-inc-3436556100?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=9onH6G6OX%2Bc4pVAS2nhClg%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-fintech-llc-3533314276?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=Mc0QslCSvj85vISFHe45Tw%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-emonics-llc-3590956876?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=gg7aX2l0KSX%2BXzHmItparw%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-snapx-ai-3589698674?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=vyEbLNJWPIH%2BZ2OATGVNcA%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-emonics-llc-3604577421?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=II3wADMmsgGvCN4qCVwwYA%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/python-developer-at-diverse-lynx-3599964111?refId=XCQ%2 ...
# 25

# %%
d=soup.find_all('div', class_="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card")

jobs_name = []

for title in d:
  jobs_name.append(title.text.strip())

print(jobs_name)
print(len(jobs_name))
# Out:
# ['Python Developer\n      \n      \n          \n\n\n\n\n\n\n            \n        Python Developer\n      \n          \n\n\n            Donato Technologies, Inc.\n          \n\n\n\n\n            Houston, TX\n          \n\n\n\n\n\n         Actively Hiring\n \n\n\n\n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      1 month ago', 'Python Developer\n      \n      \n          \n\n\n\n\n\n\n            \n        Python Developer\n      \n          \n\n\n            TEAL\n          \n\n\n\n\n            Houston, TX\n          \n\n\n\n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      3 weeks ago', 'Python Developer\n      \n      \n          \n\n\n\n\n\n\n            \n        Python Developer\n      \n          \n\n\n            MHK TECH INC\n          \n\n\n\n\n            Houston, TX\n          \n\n\n\n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      3 months ago', 'Python Developer - Remote\n      \n      \n          \n\n\n\n\n\n\n            \n        Python Developer - Remote\n      \n          \n\n\n            TensorIoT Inc.\n          \n\n\n\n\n            Houston, TX\n          \n\n\n\n\n\n         Actively Hiring\n \n\n\n\n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      2 weeks ago', 'Python developer, Hybrid, TX\n      \n      \n          \n\n\n\n\n\n\n            \n        Python developer, Hybrid, TX\n      \n          \n\n\n            Stellent IT\n          \n\n\n\n\n            Houston, TX\n          \n\n\n\n\n\n         Be an early applicant\n \n\n\n\n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      1 month ago', 'Python Developer - Remote\n      \n      \n          \n\n\n\n\n\n\n            \n        Python Developer - Remote\n      \n          \n\n\n            The Dignify Solutions, LLC\n          \n\n\n\n\n            Houston, TX\n          \n\n\n\n\n\n         Actively Hiring\n \n\n\n\n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      4 weeks ago', 'Python Developer\n      \n      \n          \n\n\n\n\n\n\n            \n        Python Developer\n      \n          \n\n\n            FinTech LLC\n          \n\n\n\n\n            Houston, TX\n          \n\n\n\n\n\n         Be an early applicant\n \n\n\n\n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      5 months ago', 'Python Developer\n      \n      \n          \n\n\n\n\n\n\n            \n        Python Developer\n      \n          \n\n\n            TekVivid, Inc\n          \n\n\n\n\n            Texas City, TX\n          \n\n\n\n\n\n         Actively Hiring\n \n\n\n\n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      2 months ago', 'Python Developer - Remote | WFH\n      \n      \n          \n\n\n\n\n\n\n            \n        Python Developer - Remote | WFH\n      \n          \n\n\n            Get It Recruit - Information T ...
# 25

# %%
# addig nan in data frame while facing value error
import pandas as pd
import numpy as np
d = {'Jobname': jobs_name, 'Joblink': joblink,}

df = pd.DataFrame(data=d)
display(df.head())
# Out:
#                                              Jobname  \
# 0  Python Developer\n      \n      \n          \n...
# 1  Python Developer\n      \n      \n          \n...
# 2  Python Developer\n      \n      \n          \n...
# 3  Python Developer - Remote\n      \n      \n   ...
# 4  Python developer, Hybrid, TX\n      \n      \n...
#
#                                              Joblink
# 0  https://www.linkedin.com/jobs/view/python-deve...
# 1  https://www.linkedin.com/jobs/view/python-deve...
# 2  https://www.linkedin.com/jobs/view/python-deve...
# 3  https://www.linkedin.com/jobs/view/python-deve...
# 4  https://www.linkedin.com/jobs/view/python-deve...

# %%
df.to_csv('basedata.csv', index=False)

# %%
import pandas as pd

dataframereading = pd.read_csv('basedata.csv')
linkslist = dataframereading['Joblink']

# %%
jobs_description = []
jobs_details = []
# jobs_name =[]
for link in linkslist:
  print(link)
  #url = 'https://www.linkedin.com/jobs/view/python-developer-at-donato-technologies-inc-3534800375?refId=XE%2FYwGrdxktzP56hrgM1qQ%3D%3D&trackingId=MJ%2BEe6RIYRul1XLOEKU7yw%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card'
  response = requests.get(link, headers = headers)
  print(response)
  soup = BeautifulSoup(response.content,'html.parser')
  jobupdate=soup.find_all('div', class_="show-more-less-html__markup")

  #jobs_details = []
  for title in jobupdate:
    jobs_details.append(title.text.strip())

  # jobname=soup.find_all('div', class_="p5")

  # #jobs_details = []
  # for jobsnames in jobname:
  #   jobs_name.append(jobsnames.text.strip())
  # print(jobs_name)
  print(jobs_details)
  print(len(jobs_details))
  jobs_description.append(jobs_details)
print(jobs_description)
# Out:
# https://www.linkedin.com/jobs/view/python-developer-at-donato-technologies-inc-3534800375?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=a7kj%2BTScgUm4TZyKGEpmIQ%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization"]
# 1
# https://www.linkedin.com/jobs/view/python-developer-at-teal-3580454578?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=K2uopErZwAD6rAWoTMxLWQ%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 2
# https://www.linkedin.com/jobs/view/python-developer-at-mhk-tech-inc-3480612830?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=wNemgoSiyiAuKu3ersCj9g%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 3
# https://www.linkedin.com/jobs/view/python-developer-remote-at-tensoriot-inc-3593022609?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=AJokef2DDzmb58lxJgpeUw%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 4
# https://www.linkedin.com/jobs/view/python-developer-hybrid-tx-at-stellent-it-3584717391?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=Y9LK1%2BY1NzGmSjD2FGBnQQ%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 5
# https://www.linkedin.com/jobs/view/python-developer-remote-at-the-dignify-solutions-llc-3569980779?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=INupXQJhoFH2GkrWc9odwA%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 6
# https://www.linkedin.com/jobs/view/python-developer-at-fintech-llc-3418387917?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=z%2FJlXWV6OMfNEwQO9DdlCw%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 7
# https://www.linkedin.com/jobs/view/python-developer-at-tekvivid-inc-3497356391?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=X3xVwWqsxX6r4O%2FreijF%2Fg%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 8
# https://www.linkedin.com/jobs/view/python-developer-remote-wfh-at-get-it-recruit-information-technology-3586560628?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=HUdnShWGR7VLXrlji4XObw%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 9
# https://www.linkedin.com/jobs/view/python-developer-at-extend-information-systems-inc-3480802978?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=S95R0tMtlN5rPlAgQO2uMw%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 10
# https://www.linkedin.com/jobs/view/python-developer-with-aws-at-donato-technologies-inc-3534838411?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=RH49awI%2B%2F5iba9dAZOZpRQ%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 11
# https://www.linkedin.com/jobs/view/python-developer-at-hermitage-infotech-3589717076?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=km9L0V%2BfohvnrMyaDf4wTw%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 12
# https://www.linkedin.com/jobs/view/python-developer-engineer-at-mhk-tech-inc-3436556100?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=9onH6G6OX%2Bc4pVAS2nhClg%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ...
# 23
# https://www.linkedin.com/jobs/view/python-developer-at-vitol-3472309701?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=%2BHleINtUbXl15OeilayTPw%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 24
# https://www.linkedin.com/jobs/view/looking-for-python-developer-houston-tx-full-time-at-extend-information-systems-inc-3480804575?refId=XCQ%2FsKurfP8K4ZxR3HC9KQ%3D%3D&trackingId=vVqlQuRDun2QJQFbf0vvHg%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card
# <Response [200]>
# ["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computin ...
# 25
# [["Title: Python DeveloperClient: JPMCLocation: Houston, TXJob DescriptionExperience 10 Years (minimum)AWS experience is must.knowledgeable with center Python web frameworks, Object social mappers.should have an understanding of the multi-process design and RESTful API's to coordinate applications with other components.Front-end development skills and database knowledge are a couple of pleasant to have skills for a product developer.Composing Python scripts and framework organization", "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity are available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, ethernet, modbus, and / or bacnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with development team in designing programs (methods/functions) in Python * Demo, Test and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate on cross functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years experience with in software development, preferably related to controls or similar * Knowledge of python, HTML, Javascript and Linux like environments * Knowledge of .net and visual studio (preferred but not required) * Knowledge of databases such as sqlite, mssql, mongodb * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first time home buyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computi ...

# %%
import pandas as pd
import numpy as np
# dd = {'Job Name': jobs_name, 'Job Descriptions': jobs_details,}
dd = {'Jobsdescriptions': jobs_details,}
dfs = pd.DataFrame(data=dd)
display(dfs.head())
# Out:
#                                     Jobsdescriptions
# 0  Title: Python DeveloperClient: JPMCLocation: H...
# 1  TEAL is revolutionizing the hydronic industry ...
# 2  Senior Python Software Engineer – 100% Remote ...
# 3  Accepting remote candidates in the following s...
# 4  Job Title : Python developerLocation : Hybrid ...

# %%
dfs.to_csv('linkedindata.csv', index=False)

# %%
import pandas as pd

# reading csv file
df = pd.read_csv("linkedindata.csv")

# filtering the rows where Credit-Rating contains an email address or phone number
df = df[df['Jobsdescriptions'].str.contains(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b|\b\d{3}[-.]?\d{3}[-.]?\d{4}\b')]
print(df)
# Out:
#                                      Jobsdescriptions
# 4   Job Title : Python developerLocation : Hybrid ...
# 9   Hi,Sourabh this side. We do have a new an exce...
# 11  Hope you are doing well. We have an urgent pos...
# 24  Hi, Jobseekers,I hope you are doing well!We ha...

# %%
df.to_csv('linkedindata1.csv', index=False)

# %%
import pandas as pd

jobdataset = pd.read_csv('linkedindata1.csv')
jobsdata = jobdataset['Jobsdescriptions'].str.strip().values.tolist()
jobsdata
# Out:
# ['Job Title : Python developerLocation : Hybrid Role, (Houston, TX 2 days Remote/3 days Onsite)Interview : Phone + SkypeJob description: Project Details: Financial forecasting project with in the data and analytics groupNeeds: Python, Package, SQLExperience: Agile development and problem solvingInterview 1st Phase (Video): Basic Coding exercise to start the interview process Python Python Package SQL 2nd Phase (Video):Problem solving - 1 hourDesign Buttons - 1 hourGeneral Questions - 1/2 hour with managersPrashant IT Technical RecruiterPhone: 732-962-1575Email: Prashant@stellentit.comGtalk: Prashant@stellentit.comhttps://www.linkedin.com/in/prashant-tyagi-790119210/',
#  "Hi,Sourabh this side. We do have a new an excellent opportunity for you. This opportunity is a Fulltime position as Python Developer On-Site Please have a look at the job description below and let me know if you or someone you know is interested in this role. You can mail me At Sourabh@extendinfosys.comJob Title Python DeveloperLocation Houston, TXJob Type Full TimeJd5+ years' experience as Python developer.Hands on experience in Django framework.Strong exposure and development experience using Time series data.Regression models (simple and more advanced techniques, linear and non-linear),Time series modellingStandard array of statistical software packages (Python, R, EViews, SAS)Azure fundamentalsPower BI foundation level knowledgeThanks,Sourabh | Technical RecruiterCell: 571-473-5044Email: Sourabh@extendinfosys.comAddress: 44258 Mercure Circle, UNIT 102 A, Sterling VA, USA - 20166Web: WWW.extendinfosys.com",
#  'Hope you are doing well. We have an urgent position for Python Developers in NY and TX.Please share a suitable profile if you’ve. Please send your resume to Varma@hermitageinfotech.com or call Varma at 732-593-8453 Extension 202 for any questions or call 732-231-6194 directly. Please mention your visa status, current location, minimum expected salary, and availability to start a new project.Role: Python Developer with 6 – 10 years of genuine experienceLocation: New York andTXDuration: 12+ monthsJob briefWe are looking for a Python Developer to join our engineering team and help us develop and maintain various software products.Python Developer responsibilities include writing and testing code, debugging programs and integrating applications with third-party web services. To be successful in this role, you should have experience using server-side logic and work well in a team.Ultimately, you’ll build highly responsive web applications that align with our business needs.Responsibilities Write effective, scalable code Develop back-end components to improve responsiveness and overall performance Integrate user-facing elements into applications Test and debug programs Improve functionality of existing systems Implement security and data protection solutions Assess and prioritize feature requests Coordinate with internal teams to understand user requirements and provide technical solutionsRequirements Work experience as a Python Developer. Expertise in at least one popular Python framework (like Django, Flask) Knowledge of object-relational mapping (ORM) Familiarity with front-end technologies (like JavaScript) Team spirit Good problem-solving skills Knowledge of virtualenv concept. Git/GitHubVarmaHermitage Infotech, LLCP:732-593-8453 Extension 202F:732-289-6103varma@hermitageinfotech.comwww.hermitageinfotech.com',
#  "Hi, Jobseekers,I hope you are doing well!We have an opportunity for Python Developer with one of our clients for Houston, TX.Please see the job details below and let me know if you would be interested in this role.If interested, please send me a copy of your resume, contact details, availability, and a good time to connect with you.Title: Python DeveloperLocation: Houston, TXTerms: Full-timeJob Details5+ years' experience as Python developer.Hands on experience in Django framework.Strong exposure and development experience using Time series data.Regression models (simple and more advanced techniques, linear and non-linear),Time series modellingStandard array of statistical software packages (Python, R, EViews, SAS)Azure fundamentalsPower BI foundation level knowledgeThanks & RegardsMonika SinghExtend Information System IncPhone:571-622-3980 Email: monika@extendinfosys.com44258 Mercure Circle, UNIT 102 A, Sterling VA, USA 20166"]

# %%
import re

def extract_contact_info(text):
    # Regular expressions for matching phone numbers and email addresses
    phone_regex = r'\b\d{3}[-.]?\d{3}[-.]?\d{4}\b'
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

    # Find all matches of phone numbers and email addresses in the text
    phone_numbers = re.findall(phone_regex, text)
    email_addresses = re.findall(email_regex, text)

    return phone_numbers, email_addresses

# Example usage
# text_list = [
#     'Role - Python DeveloperLocation - Houston, TX (ONSITE)Type - CONTRACT/FULLTIMEJob Description10 Years + of overall software development experience; PythonKnowledge and experience in Python, Django, Angular JS, Oracle highly desirable.Knowledge of version and revision control practices and proceduresWorking experience with database environment - understanding relational database structure and hands-on SQL knowledge to extract/manipulate data.At least 1+ years of experience in an Investment Bank (or similar) as a DeveloperSolid application design, development, and testing work experience.Strong sense of ownership, ability to work independently, and have strong communication skills.',
#     # Add more text elements here if needed
# ]
text_list = jobsdata
all_phone_numbers = []
all_email_addresses = []

for text in text_list:
    phone_numbers, email_addresses = extract_contact_info(text)
    all_phone_numbers.extend(phone_numbers)
    all_email_addresses.extend(email_addresses)

# Print the extracted phone numbers and email addresses
print("Phone Numbers:")
for phone_number in all_phone_numbers:
    print(phone_number)

print("\nEmail Addresses:")
for email_address in all_email_addresses:
    print(email_address)
# Out:
# Phone Numbers:
# 732-593-8453
# 732-231-6194
# 732-593-8453
# 571-622-3980
#
# Email Addresses:
# Prashant@stellentit.comGtalk
# Prashant@stellentit.comhttps
# Sourabh@extendinfosys.comJob
# Sourabh@extendinfosys.comAddress
# Varma@hermitageinfotech.com
# 732-289-6103varma@hermitageinfotech.comwww.hermitageinfotech.com

# %%
import csv
from itertools import zip_longest

# phone_numbers = ['732-593-8453', '732-231-6194', '732-593-8453', '571-622-3980']
# descriptions = ['Prashant@stellentit.comGtalk', 'Prashant@stellentit.comhttps', 'Sourabh@extendinfosys.comJob', 'Sourabh@extendinfosys.comAddress', 'Varma@hermitageinfotech.com', '732-289-6103varma@hermitageinfotech.comwww.hermitageinfotech.com']
phone_numbers = all_phone_numbers
descriptions = all_email_addresses
# Fill missing values with empty strings
filled_values = zip_longest(phone_numbers, descriptions, fillvalue='')

# Write the filled values to a CSV file
with open('output.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Phone Number', 'Email'])
    writer.writerows(filled_values)

# %%
df4 = pd.read_csv('linkedindata1.csv')
df5 = pd.read_csv('output.csv')

# %%
# df_merged = df4.merge(df5, right_on=None)
# df_merged

# %%
import pandas as pd
from itertools import zip_longest

# phone_numbers = ['732-593-8453', '732-231-6194', '732-593-8453', '571-622-3980']
# descriptions = ['Prashant@stellentit.comGtalk', 'Prashant@stellentit.comhttps', 'Sourabh@extendinfosys.comJob', 'Sourabh@extendinfosys.comAddress', 'Varma@hermitageinfotech.com', '732-289-6103varma@hermitageinfotech.comwww.hermitageinfotech.com']
phone_numbers = all_phone_numbers
descriptions = all_email_addresses
# Fill missing values with empty strings
filled_values = zip_longest(phone_numbers, descriptions, fillvalue='')

# Create a DataFrame from the filled values
df = pd.DataFrame(filled_values, columns=['Phone Number', 'Email'])

# Write the DataFrame to a CSV file
df.to_csv('outputdata.csv', index=False)

# %%
import pandas as pd

# data = [
#     # Your list of job descriptions
# ]

data = jobsdata

df = pd.DataFrame(data, columns=['job_description'])
# phone_numbers = ['1234567890', '9876543210']  # Example phone numbers to filter
# keywords = ['python', 'developer']  # Example keywords to filter
phone_numbers = all_phone_numbers  # Example phone numbers to filter
emailids = all_email_addresses  # Example keywords to filter

# Filter the rows that contain any of the phone numbers or keywords in the job description
filtered_df = df[df['job_description'].str.contains('|'.join(phone_numbers), case=False)]

# Save the filtered data to a CSV file
filtered_df.to_csv('filtered_jobs.csv', index=False)

# %%
import pandas as pd

# data = [
#     # Your list of job descriptions
# ]

data = jobsdata

df = pd.DataFrame(data, columns=['job_description'])
# phone_numbers = ['1234567890', '9876543210']  # Example phone numbers to filter
# keywords = ['python', 'developer']  # Example keywords to filter
phone_numbers = all_phone_numbers  # Example phone numbers to filter
emailids = all_email_addresses  # Example keywords to filter

# Filter the rows that contain any of the phone numbers or keywords in the job description
filtered_df = df[df['job_description'].str.contains('|'.join(emailids), case=False)]

# Save the filtered data to a CSV file
filtered_df.to_csv('efiltered_jobs.csv', index=False)

# %%
# import pandas as pd

# # Assuming filtered_df, phone_numbers, and descriptions are already defined

# # Create a DataFrame with the filtered data
# data = {'Filtered Data': filtered_df, 'Phone Numbers': phone_numbers, 'Descriptions': descriptions}
# df = pd.DataFrame(data)

# # Write the DataFrame to a CSV file
# df.to_csv('filtered_data.csv', index=False)

# %%
import pandas as pd
from itertools import zip_longest

# phone_numbers = ['732-593-8453', '732-231-6194', '732-593-8453', '571-622-3980']
# descriptions = ['Prashant@stellentit.comGtalk', 'Prashant@stellentit.comhttps', 'Sourabh@extendinfosys.comJob', 'Sourabh@extendinfosys.comAddress', 'Varma@hermitageinfotech.com', '732-289-6103varma@hermitageinfotech.comwww.hermitageinfotech.com']
phone_numbers = all_phone_numbers
descriptions = all_email_addresses
# Fill missing values with empty strings
filled_values = zip_longest(filtered_df.values.tolist(), phone_numbers, descriptions, fillvalue='')

# Create a DataFrame from the filled values
df = pd.DataFrame(filled_values, columns=['Jobdescription', 'Phone Number', 'Email'])

# Write the DataFrame to a CSV file
df.to_csv('outputdata.csv', index=False)

# %%
filtered_df.values
filtered_df
print(type(phone_numbers))
print(type(filtered_df.values.tolist()))
# Out:
# <class 'list'>
# <class 'list'>

# %%
import re

def extract_contact_info(text, column_name):
    # Regular expressions for matching phone numbers and email addresses
    phone_regex = r'\b\d{3}[-.]?\d{3}[-.]?\d{4}\b'
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

    # Find all matches of phone numbers and email addresses in the text
    phone_numbers = re.findall(phone_regex, text)
    email_addresses = re.findall(email_regex, text)

    # Add column name or relevant information to the extracted contact information
    extracted_info = [(column_name, number) for number in phone_numbers] + [(column_name, email) for email in email_addresses]

    return extracted_info

# Example usage
jobsdata = [
    {
        'id': 1,
        'description': 'Role - Python Developer\nLocation - Houston, TX (ONSITE)\nType - CONTRACT/FULLTIME\nJob Description\n10 Years + of overall software development experience; Python\nKnowledge and experience in Python, Django, Angular JS, Oracle highly desirable.\nKnowledge of version and revision control practices and procedures\nWorking experience with database environment - understanding relational database structure and hands-on SQL knowledge to extract/manipulate data.\nAt least 1+ years of experience in an Investment Bank (or similar) as a Developer\nSolid application design, development, and testing work experience.\nStrong sense of ownership, ability to work independently, and have strong communication skills.'
    },
    # Add more job descriptions here if needed
]

all_contact_info = []

for job in jobsdata:
    job_id = job['id']
    description = job['description']
    contact_info = extract_contact_info(description, f'Job ID: {job_id}')
    all_contact_info.extend(contact_info)

# Print the extracted contact information
for info in all_contact_info:
    column_name, contact = info
    print(f"{column_name}: {contact}")

# %%
import re
import csv

def extract_contact_info(text):
    # Regular expressions for matching phone numbers and email addresses
    phone_regex = r'\b\d{3}[-.]?\d{3}[-.]?\d{4}\b'
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

    # Find all matches of phone numbers and email addresses in the text
    phone_numbers = re.findall(phone_regex, text)
    email_addresses = re.findall(email_regex, text)

    return phone_numbers, email_addresses

# # Example usage
# jobsdata = [
#     "Title: Python Developer\nClient: JPMC\nLocation: Houston, TX\nJob Description\nExperience 10 Years (minimum)\nAWS experience is a must.\nKnowledgeable with center Python web frameworks, Object social mappers.\nShould have an understanding of the multi-process design and RESTful APIs to coordinate applications with other components.\nFront-end development skills and database knowledge are a couple of pleasant-to-have skills for a product developer.\nComposing Python scripts and framework organization",
#     "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity is available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing, and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, Ethernet, Modbus, and/or BACnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with the development team in designing programs (methods/functions) in Python * Demo, Test, and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate in cross-functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years of experience in software development, preferably related to controls or similar * Knowledge of Python, HTML, JavaScript, and Linux-like environments * Knowledge of .NET and Visual Studio (preferred but not required) * Knowledge of databases such as SQLite, MSSQL, MongoDB * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first-time homebuyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computing for 24/7/365 remote monitoring. Discover your managed mechanical systems as-a-service delivering uninterrupted chilled water, domestic hot water, and hydronic heat for residential and commercial developments of any size, nationwide.TEAL offers a centralized system that leverages cloud-based computing for 24/7/365 remote monitoring. Discover your managed mechanical systems as-a-service delivering uninterrupted chilled water, domestic hot water, and hydronic heat for residential and commercial developments of any size, nationwide.",
# ]

jobsdata = jobsdata

filtered_data = []

for job_description in jobsdata:
    phone_numbers, email_addresses = extract_contact_info(job_description)
    filtered_data.append([job_description, ", ".join(phone_numbers), ", ".join(email_addresses)])

# Write the filtered data to a CSV file
with open("filtered_data.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Job Description", "Phone Numbers", "Email Addresses"])
    writer.writerows(filtered_data)

# %%
import re
import csv

def extract_contact_info(text):
    # Regular expressions for matching phone numbers and email addresses
    phone_regex = r'\b\d{3}[-.]?\d{3}[-.]?\d{4}\b'
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

    # Find all matches of phone numbers and email addresses in the text
    phone_numbers = re.findall(phone_regex, text)
    email_addresses = re.findall(email_regex, text)

    return phone_numbers, email_addresses

# jobsdata = [
#     "Title: Python Developer\nClient: JPMC\nLocation: Houston, TX\nJob Description\nExperience 10 Years (minimum)\nAWS experience is a must.\nKnowledgeable with center Python web frameworks, Object social mappers.\nShould have an understanding of the multi-process design and RESTful APIs to coordinate applications with other components.\nFront-end development skills and database knowledge are a couple of pleasant-to-have skills for a product developer.\nComposing Python scripts and framework organization",
#     "TEAL is revolutionizing the hydronic industry by humanizing Hot Water, Chilled Water & Hydronic Heat. TEAL's innovation design - incorporating advanced AI technology and remote monitoring - far outperforms traditional central plants, resulting in a significantly reduced carbon footprint and the lowest total lifecycle cost. The future of central plants and your next opportunity is available today! POSITION OVERVIEW: Teal is seeking a professional, skilled Python Software Developer for our Controls team. The successful candidate will work with the Teal software development team to develop and sustain technologies for HVAC commercial products. Teal operates an IOT network, which manages the operation and optimization of a distributed infrastructure system. Each node in the network uses a Teal control module to acquire data and transmit control logic to the underlying hardware. The sites utilize common HVAC hardware including air handlers, fan coils, chillers, heat pumps, and boilers. The responsibilities of this position include the design, analysis, testing, and documentation of software integrated into the control PCBs (embedded computer controllers). The control module designs use Wi-Fi, Ethernet, Modbus, and/or BACnet for communication. The Software Developer will work with the onshore and offshore team in managing ECC upgrades and new functionality from prototype through to production. KEY RESPONSIBILITIES: * Work with the development team in designing programs (methods/functions) in Python * Demo, Test, and qualify existing and new functionality * Identify opportunities within the existing and future firmware for continuous improvement * Use communication protocols to send and receive data from various devices * Contribute to the Agile framework, used to manage projects from concept to release * Document activities (requirements, code, schematics, layouts, etc.) * Participate in cross-functional teams to launch products, resolve issues, and support product improvements * Work with Data Science on managing data from IOT network through data factory to analytics * Drive continuous improvement projects related to product design and quality QUALIFICATIONS & SKILLS: * Bachelor's degree in Electrical Engineering or Computer Science * 5+ years of experience in software development, preferably related to controls or similar * Knowledge of Python, HTML, JavaScript, and Linux-like environments * Knowledge of .NET and Visual Studio (preferred but not required) * Knowledge of databases such as SQLite, MSSQL, MongoDB * Knowledge of consuming and calling REST APIs * Experience with ADC/DAC controls * Effective communication skills - both oral and written COMPENSATION & BENEFITS: * PTO Allotment of 120 hours / 3 weeks after 90 days of employment * Competitive Compensation * Holistic Health Coverage (medical, dental, vision, life insurance, disability), including 24/7 medical concierge services * 401k Plan with a generous employer match * 10 Paid Holidays and Birthdays off * Cell Phone Allowance * Memberships to professional organizations are paid for by the Company * Casual Dress Code * $500 cash for first-time homebuyers! * Teambuilding - Have fun with the team at sporting events, lunches, and other group festivities * Excellent growth and advancement opportunities. TEAL is an Equal Opportunity Employer. TEAL requires pre-employment background checks and drug screening. Company Description TEAL offers a centralized system that leverages cloud-based computing for 24/7/365 remote monitoring. Discover your managed mechanical systems as-a-service delivering uninterrupted chilled water, domestic hot water, and hydronic heat for residential and commercial developments of any size, nationwide.TEAL offers a centralized system that leverages cloud-based computing for 24/7/365 remote monitoring. Discover your managed mechanical systems as-a-service delivering uninterrupted chilled water, domestic hot water, and hydronic heat for residential and commercial developments of any size, nationwide.",
# ]

jobsdata = jobsdata
filtered_data = []

for job_description in jobsdata:
    phone_numbers, email_addresses = extract_contact_info(job_description)
    filtered_data.append([job_description, phone_numbers, email_addresses])

# Write the filtered data to a CSV file
with open("filtered_data.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Job Description", "Phone Numbers", "Email Addresses"])
    writer.writerows(filtered_data)

# %%
import re
import csv

def extract_contact_info(text):
    # Regular expressions for matching phone numbers and email addresses
    phone_regex = r'\b\d{3}[-.]?\d{3}[-.]?\d{4}\b'
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

    # Find all matches of phone numbers and email addresses in the text
    phone_numbers = re.findall(phone_regex, text)
    email_addresses = re.findall(email_regex, text)

    return phone_numbers, email_addresses

# jobsdata = ['Hope you are doing well. We have an urgent position for Python Developers in NY and TX.Please share a suitable profile if you’ve. Please send your resume to Varma@hermitageinfotech.com or call Varma at 732-593-8453 Extension 202 for any questions or call 732-231-6194 directly. Please mention your visa status, current location, minimum expected salary, and availability to start a new project.Role: Python Developer with 6 – 10 years of genuine experienceLocation: New York andTXDuration: 12+ monthsJob briefWe are looking for a Python Developer to join our engineering team and help us develop and maintain various software products.Python Developer responsibilities include writing and testing code, debugging programs and integrating applications with third-party web services. To be successful in this role, you should have experience using server-side logic and work well in a team.Ultimately, you’ll build highly responsive web applications that align with our business needs.Responsibilities Write effective, scalable code Develop back-end components to improve responsiveness and overall performance Integrate user-facing elements into applications Test and debug programs Improve functionality of existing systems Implement security and data protection solutions Assess and prioritize feature requests Coordinate with internal teams to understand user requirements and provide technical solutionsRequirements Work experience as a Python Developer. Expertise in at least one popular Python framework (like Django, Flask) Knowledge of object-relational mapping (ORM) Familiarity with front-end technologies (like JavaScript) Team spirit Good problem-solving skills Knowledge of virtualenv concept. Git/GitHubVarmaHermitage Infotech, LLCP:732-593-8453 Extension 202F:732-289-6103varma@hermitageinfotech.comwww.hermitageinfotech.com',]

jobsdata = jobsdata
filtered_data = []

for job_description in jobsdata:
    phone_numbers, email_addresses = extract_contact_info(job_description)
    filtered_data.append([job_description, phone_numbers[0] if phone_numbers else '', email_addresses[0] if email_addresses else ''])

# Write the filtered data to a CSV file
with open("filtered_dataset.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Job Description", "Phone Number", "Email Address"])
    writer.writerows(filtered_data)

# %%
import re
import csv

def extract_contact_info(text):
    # Regular expressions for matching phone numbers and email addresses
    phone_regex = r'\b\d{3}[-.]?\d{3}[-.]?\d{4}\b'
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'
    # phone_regex = r'(\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b)'
    # email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

    # Find all matches of phone numbers and email addresses in the text
    phone_numbers = re.findall(phone_regex, text)
    email_addresses = re.findall(email_regex, text)

    return phone_numbers, email_addresses

# jobsdata = [
#     'Hope you are doing well. We have an urgent position for Python Developers in NY and TX.Please share a suitable profile if you’ve. Please send your resume to Varma@hermitageinfotech.com or call Varma at 732-593-8453 Extension 202 for any questions or call 732-231-6194 directly. Please mention your visa status, current location, minimum expected salary, and availability to start a new project.Role: Python Developer with 6 – 10 years of genuine experienceLocation: New York andTXDuration: 12+ monthsJob briefWe are looking for a Python Developer to join our engineering team and help us develop and maintain various software products.Python Developer responsibilities include writing and testing code, debugging programs and integrating applications with third-party web services. To be successful in this role, you should have experience using server-side logic and work well in a team.Ultimately, you’ll build highly responsive web applications that align with our business needs.Responsibilities Write effective, scalable code Develop back-end components to improve responsiveness and overall performance Integrate user-facing elements into applications Test and debug programs Improve functionality of existing systems Implement security and data protection solutions Assess and prioritize feature requests Coordinate with internal teams to understand user requirements and provide technical solutionsRequirements Work experience as a Python Developer. Expertise in at least one popular Python framework (like Django, Flask) Knowledge of object-relational mapping (ORM) Familiarity with front-end technologies (like JavaScript) Team spirit Good problem-solving skills Knowledge of virtualenv concept. Git/GitHubVarmaHermitage Infotech, LLCP:732-593-8453 Extension 202F:732-289-6103varma@hermitageinfotech.comwww.hermitageinfotech.com',
#     'Job Title : Python developerLocation : Hybrid Role, (Houston, TX 2 days Remote/3 days Onsite)Interview : Phone + SkypeJob description: Project Details: Financial forecasting project with in the data and analytics groupNeeds: Python, Package, SQLExperience: Agile development and problem solvingInterview 1st Phase (Video): Basic Coding exercise to start the interview process Python Python Package SQL 2nd Phase (Video):Problem solving - 1 hourDesign Buttons - 1 hourGeneral Questions - 1/2 hour with managersPrashant IT Technical RecruiterPhone: 732-962-1575Email: Prashant@stellentit.comGtalk: Prashant@stellentit.comhttps://www.linkedin.com/in/prashant-tyagi-790119210/',
#     'Hi,Sourabh this side. We do have a new an excellent opportunity for you. This opportunity is a Fulltime position as Python Developer On-Site Please have a look at the job description below and let me know if you or someone you know is interested in this role. You can mail me At Sourabh@extendinfosys.comJob Title Python DeveloperLocation Houston, TXJob Type Full TimeJd5+ years\' experience as Python developer.Hands on experience in Django framework.Strong exposure and development experience using Time series data.Regression models (simple and more advanced techniques, linear and non-linear),Time series modellingStandard array of statistical software packages (Python, R, EViews, SAS)Azure fundamentalsPower BI foundation level knowledgeThanks,Sourabh | Technical RecruiterCell: 571-473-5044Email: Sourabh@extendinfosys.comAddress: 44258 Mercure Circle, UNIT 102 A, Sterling VA, USA - 20166Web: WWW.extendinfosys.com',
#     'Hi, Jobseekers,I hope you are doing well!We have an opportunity for Python Developer with one of our clients for Houston, TX.Please see the job details below and let me know if you would be interested in this role.If interested, please send me a copy of your resume, contact details, availability, and a good time to connect with you.Title: Python DeveloperLocation: Houston, TXTerms: Full-timeJob Details5+ years\' experience as Python developer.Hands on experience in Django framework.Strong exposure and development experience using Time series data.Regression models (simple and more advanced techniques, linear and non-linear),Time series modellingStandard array of statistical software packages (Python, R, EViews, SAS)Azure fundamentalsPower BI foundation level knowledgeThanks & RegardsMonika SinghExtend Information System IncPhone:571-622-3980 Email: monika@extendinfosys.com44258 Mercure Circle, UNIT 102 A, Sterling VA, USA 20166'
# ]

jobsdata = jobsdata
filtered_data = []

for job_description in jobsdata:
    phone_numbers, email_addresses = extract_contact_info(job_description)
    filtered_data.append([job_description, phone_numbers[0] if phone_numbers else '', email_addresses[0] if email_addresses else ''])

# Write the filtered data to a CSV file
with open("filtered_datas.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Job Description", "Phone Number", "Email Address"])
    writer.writerows(filtered_data)

# %%
import pandas as pd

# reading csv file
df = pd.read_csv("linkedindata.csv")

# filtering the rows where Jobsdescriptions contain an email address or phone number
filtered_df = df[df['Jobsdescriptions'].str.contains(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b|\b\d{3}[-.]?\d{3}[-.]?\d{4}\b')]

# extract email addresses and mobile numbers into separate columns
filtered_df['email'] = filtered_df['Jobsdescriptions'].str.extract(r'(\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b)', flags=re.IGNORECASE)
filtered_df['mobile_number'] = filtered_df['Jobsdescriptions'].str.extract(r'(\b\d{3}[-.]?\d{3}[-.]?\d{4}\b)')

# print the filtered DataFrame with email and mobile number columns
print(filtered_df)
# Out:
#                                      Jobsdescriptions  \
# 4   Job Title : Python developerLocation : Hybrid ...
# 9   Hi,Sourabh this side. We do have a new an exce...
# 11  Hope you are doing well. We have an urgent pos...
# 24  Hi, Jobseekers,I hope you are doing well!We ha...
#
#                            email mobile_number
# 4   Prashant@stellentit.comGtalk           NaN
# 9   Sourabh@extendinfosys.comJob           NaN
# 11   Varma@hermitageinfotech.com  732-593-8453
# 24                           NaN  571-622-3980
# <ipython-input-35-96c1893c2e60>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['email'] = filtered_df['Jobsdescriptions'].str.extract(r'(\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b)', flags=re.IGNORECASE)
# <ipython-input-35-96c1893c2e60>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['mobile_number'] = filtered_df['Jobsdescriptions'].str.extract(r'(\b\d{3}[-.]?\d{3}[-.]?\d{4}\b)')

# %%
filtered_df['email']
filtered_df['mobile_number']
# Out:
# 4              NaN
# 9              NaN
# 11    732-593-8453
# 22    571-622-3980
# Name: mobile_number, dtype: object

# %%
import re
import csv

def extract_contact_info(text):
    # Regular expressions for matching phone numbers and email addresses
    # phone_regex = r'\b\d{3}[-.]?\d{3}[-.]?\d{4}\b'
    # email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'
    phone_regex = r'(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})'
    #email_regex = r"([-!#-'*+/-9=?A-Z^-~]+(\.[-!#-'*+/-9=?A-Z^-~]+)*|\"([]!#-[^-~ \t]|(\\[\t -~]))+\")@([-!#-'*+/-9=?A-Z^-~]+(\.[-!#-'*+/-9=?A-Z^-~]+)*|\[[\t -Z^-~]*])"
    #email_regex = r"(\b[A-Za-z0-9._%+-]+@[\w.-]+(?=\.com))"#working
    #email_regex = r'(\b[A-Za-z0-9._%+-]+@[\w.-]+\.com\b)'
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'#working
    # Find all matches of phone numbers and email addresses in the text
    phone_numbers = re.findall(phone_regex, text)
    email_addresses = re.findall(email_regex, text)
    #print(email_addresses)
    return phone_numbers, email_addresses

# jobsdata = [
#     'Hope you are doing well. We have an urgent position for Python Developers in NY and TX.Please share a suitable profile if you’ve. Please send your resume to Varma@hermitageinfotech.com or call Varma at 732-593-8453 Extension 202 for any questions or call 732-231-6194 directly. Please mention your visa status, current location, minimum expected salary, and availability to start a new project.Role: Python Developer with 6 – 10 years of genuine experienceLocation: New York andTXDuration: 12+ monthsJob briefWe are looking for a Python Developer to join our engineering team and help us develop and maintain various software products.Python Developer responsibilities include writing and testing code, debugging programs and integrating applications with third-party web services. To be successful in this role, you should have experience using server-side logic and work well in a team.Ultimately, you’ll build highly responsive web applications that align with our business needs.Responsibilities Write effective, scalable code Develop back-end components to improve responsiveness and overall performance Integrate user-facing elements into applications Test and debug programs Improve functionality of existing systems Implement security and data protection solutions Assess and prioritize feature requests Coordinate with internal teams to understand user requirements and provide technical solutionsRequirements Work experience as a Python Developer. Expertise in at least one popular Python framework (like Django, Flask) Knowledge of object-relational mapping (ORM) Familiarity with front-end technologies (like JavaScript) Team spirit Good problem-solving skills Knowledge of virtualenv concept. Git/GitHubVarmaHermitage Infotech, LLCP:732-593-8453 Extension 202F:732-289-6103varma@hermitageinfotech.comwww.hermitageinfotech.com',
#     'Job Title : Python developerLocation : Hybrid Role, (Houston, TX 2 days Remote/3 days Onsite)Interview : Phone + SkypeJob description: Project Details: Financial forecasting project with in the data and analytics groupNeeds: Python, Package, SQLExperience: Agile development and problem solvingInterview 1st Phase (Video): Basic Coding exercise to start the interview process Python Python Package SQL 2nd Phase (Video):Problem solving - 1 hourDesign Buttons - 1 hourGeneral Questions - 1/2 hour with managersPrashant IT Technical RecruiterPhone: 732-962-1575Email: Prashant@stellentit.comGtalk: Prashant@stellentit.comhttps://www.linkedin.com/in/prashant-tyagi-790119210/',
#     'Hi,Sourabh this side. We do have a new an excellent opportunity for you. This opportunity is a Fulltime position as Python Developer On-Site Please have a look at the job description below and let me know if you or someone you know is interested in this role. You can mail me At Sourabh@extendinfosys.comJob Title Python DeveloperLocation Houston, TXJob Type Full TimeJd5+ years\' experience as Python developer.Hands on experience in Django framework.Strong exposure and development experience using Time series data.Regression models (simple and more advanced techniques, linear and non-linear),Time series modellingStandard array of statistical software packages (Python, R, EViews, SAS)Azure fundamentalsPower BI foundation level knowledgeThanks,Sourabh | Technical RecruiterCell: 571-473-5044Email: Sourabh@extendinfosys.comAddress: 44258 Mercure Circle, UNIT 102 A, Sterling VA, USA - 20166Web: WWW.extendinfosys.com',
#     'Hi, Jobseekers,I hope you are doing well!We have an opportunity for Python Developer with one of our clients for Houston, TX.Please see the job details below and let me know if you would be interested in this role.If interested, please send me a copy of your resume, contact details, availability, and a good time to connect with you.Title: Python DeveloperLocation: Houston, TXTerms: Full-timeJob Details5+ years\' experience as Python developer.Hands on experience in Django framework.Strong exposure and development experience using Time series data.Regression models (simple and more advanced techniques, linear and non-linear),Time series modellingStandard array of statistical software packages (Python, R, EViews, SAS)Azure fundamentalsPower BI foundation level knowledgeThanks & RegardsMonika SinghExtend Information System IncPhone:571-622-3980 Email: monika@extendinfosys.com44258 Mercure Circle, UNIT 102 A, Sterling VA, USA 20166'
# ]

jobsdata = jobsdata
filtered_data = []

for job_description in jobsdata:
    phone_numbers, email_addresses = extract_contact_info(job_description)
    filtered_data.append([job_description, phone_numbers[0] if phone_numbers else '', email_addresses[0] if email_addresses else ''])

# Write the filtered data to a CSV file
with open("filtered_datas.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Job Description", "Phone Number", "Email Address"])
    writer.writerows(filtered_data)

# %%
filtered_df['email'] = filtered_df['Jobsdescriptions'].str.extract(r'(\b[A-Za-z0-9._%+-]+@[\w.-]+\.(?=com)\b)', flags=re.IGNORECASE)
# Out:
# <ipython-input-42-53fdc36dad42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['email'] = filtered_df['Jobsdescriptions'].str.extract(r'(\b[A-Za-z0-9._%+-]+@[\w.-]+\.(?=com)\b)', flags=re.IGNORECASE)

# %%
filtered_df['email']
# Out:
# 4         Prashant@stellentit.
# 9       Sourabh@extendinfosys.
# 11    Varma@hermitageinfotech.
# 22       monika@extendinfosys.
# Name: email, dtype: object
